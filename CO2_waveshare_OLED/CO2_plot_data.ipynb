# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fname = r"sensor_data_20260514_ueberNacht.csv"

# %%
data = pd.read_csv(fname)

# %%
data
# Out:
#      datetime  CO2 [PPM]  Temp [C]  relHum [%]
# 0        0.01   978.1640     22.74       40.59
# 1      300.23   977.8602     22.66       40.44
# 2      600.44   948.2174     22.60       40.46
# 3      900.66   937.1540     22.61       40.56
# 4     1200.88   918.8636     22.51       40.69
# ..        ...        ...       ...         ...
# 96   28821.54   751.7782     21.57       42.14
# 97   29121.86   749.1598     21.53       42.21
# 98   29422.07   750.5216     21.57       42.18
# 99   29722.29   748.3350     21.61       42.26
# 100  30022.52   753.9400     21.60       42.22
#
# [101 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    101 non-null    float64
#  1   CO2 [PPM]   101 non-null    float64
#  2   Temp [C]    101 non-null    float64
#  3   relHum [%]  101 non-null    float64
# dtypes: float64(4)
# memory usage: 3.3 KB

# %%
t0 = pd.Timestamp('2026-05-13 20:30:00')
data.index = t0 + pd.to_timedelta(data['datetime'], unit='s')
data.index.name = 'timestamp'
data
