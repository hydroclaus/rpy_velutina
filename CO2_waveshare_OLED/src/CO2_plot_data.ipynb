# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
fname = r"../data/sensor_data_2026-05-14 10:34:34.csv"

# %%
data = pd.read_csv(fname)

# %%
data
# Out:
#                        datetime  seconds_since_start  CO2 [PPM]  Temp [C]  \
# 0    2026-05-14 10:34:34.835311                 2.24  1165.5564     23.25
# 1    2026-05-14 10:39:34.984261               302.34  1210.7916     23.29
# 2    2026-05-14 10:44:35.074890               602.49  1160.7230     23.32
# 3    2026-05-14 10:49:35.173778               902.58  1167.9180     23.25
# 4    2026-05-14 10:54:35.236849              1202.67  1130.5496     23.23
# ..                          ...                  ...        ...       ...
# 258  2026-05-15 08:04:59.963156             77427.16   763.5716     21.60
# 259  2026-05-15 08:10:00.052646             77727.26   764.2372     21.64
# 260  2026-05-15 08:15:00.149574             78027.40   767.8588     21.61
# 261  2026-05-15 08:20:00.243597             78327.46   767.7262     21.68
# 262  2026-05-15 08:25:00.290349             78627.54   773.1326     21.70
#
#      relHum [%]
# 0         40.20
# 1         40.26
# 2         40.12
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   datetime             263 non-null    object
#  1   seconds_since_start  263 non-null    float64
#  2   CO2 [PPM]            263 non-null    float64
#  3   Temp [C]             263 non-null    float64
#  4   relHum [%]           263 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 10.4+ KB

# %%
data.index = pd.to_datetime(data['datetime'])

# %%
data.head()
# Out:
#                                               datetime  seconds_since_start  \
# datetime
# 2026-05-14 10:34:34.835311  2026-05-14 10:34:34.835311                 2.24
# 2026-05-14 10:39:34.984261  2026-05-14 10:39:34.984261               302.34
# 2026-05-14 10:44:35.074890  2026-05-14 10:44:35.074890               602.49
# 2026-05-14 10:49:35.173778  2026-05-14 10:49:35.173778               902.58
# 2026-05-14 10:54:35.236849  2026-05-14 10:54:35.236849              1202.67
#
#                             CO2 [PPM]  Temp [C]  relHum [%]
# datetime
# 2026-05-14 10:34:34.835311  1165.5564     23.25       40.20
# 2026-05-14 10:39:34.984261  1210.7916     23.29       40.26
# 2026-05-14 10:44:35.074890  1160.7230     23.32       40.12
# 2026-05-14 10:49:35.173778  1167.9180     23.25       40.17
# 2026-05-14 10:54:35.236849  1130.5496     23.23       40.20

# %%
# t0 = pd.Timestamp('2026-05-13 20:30:00')
# data.index = t0 + pd.to_timedelta(data['datetime'], unit='s')
# data.index.name = 'timestamp'

variables = ['CO2 [PPM]', 'Temp [C]', 'relHum [%]']
ax = data.plot(y=variables, lw=2, subplots=True, grid=True)
for a, lbl in zip(ax, variables):
    a.set_ylabel(lbl)

now = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
plt.tight_layout()
plt.savefig(f'../figs/sensor_data_plot_{now}.png')
