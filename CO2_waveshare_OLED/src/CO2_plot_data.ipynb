# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
fname = r"../data/sensor_data_2026-05-16 09:38:50.csv"

# %%
data = pd.read_csv(fname)

# %%
data
# Out:
#                         datetime  seconds_since_start  CO2 [PPM]  Temp [C]  \
# 0     2026-05-16 09:38:54.148697                  3.0     924.76     22.56
# 1     2026-05-16 09:43:54.399457                303.0     959.90     22.66
# 2     2026-05-16 09:48:54.559100                603.0     966.83     22.57
# 3     2026-05-16 09:53:54.757497                903.0     938.55     22.56
# 4     2026-05-16 09:58:54.971075               1204.0     927.21     22.58
# ...                          ...                  ...        ...       ...
# 1105  2026-05-20 05:47:41.517085             331730.0     707.75     21.68
# 1106  2026-05-20 05:52:41.723768             332030.0     700.51     21.71
# 1107  2026-05-20 05:57:41.932378             332330.0     712.85     21.74
# 1108  2026-05-20 06:02:42.134925             332630.0     719.03     21.73
# 1109  2026-05-20 06:07:42.343846             332930.0     744.17     21.74
#
#       relHum [%]
# 0          41.21
# 1          41.23
# 2          41.32
# 3          41.50
# 4          41.39
# ...          ...
# 1105       43.24
# 1106       43.19
# 1107       43.34
# 1108       43.31
# 1109       43.87
#
# [1110 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   datetime             1110 non-null   object
#  1   seconds_since_start  1110 non-null   float64
#  2   CO2 [PPM]            1110 non-null   float64
#  3   Temp [C]             1110 non-null   float64
#  4   relHum [%]           1110 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 43.5+ KB

# %%
data.index = pd.to_datetime(data['datetime'])

# %%
data.head()
# Out:
#                                               datetime  seconds_since_start  \
# datetime
# 2026-05-16 09:38:54.148697  2026-05-16 09:38:54.148697                  3.0
# 2026-05-16 09:43:54.399457  2026-05-16 09:43:54.399457                303.0
# 2026-05-16 09:48:54.559100  2026-05-16 09:48:54.559100                603.0
# 2026-05-16 09:53:54.757497  2026-05-16 09:53:54.757497                903.0
# 2026-05-16 09:58:54.971075  2026-05-16 09:58:54.971075               1204.0
#
#                             CO2 [PPM]  Temp [C]  relHum [%]
# datetime
# 2026-05-16 09:38:54.148697     924.76     22.56       41.21
# 2026-05-16 09:43:54.399457     959.90     22.66       41.23
# 2026-05-16 09:48:54.559100     966.83     22.57       41.32
# 2026-05-16 09:53:54.757497     938.55     22.56       41.50
# 2026-05-16 09:58:54.971075     927.21     22.58       41.39

# %%
# t0 = pd.Timestamp('2026-05-13 20:30:00')
# data.index = t0 + pd.to_timedelta(data['datetime'], unit='s')
# data.index.name = 'timestamp'

variables = ['CO2 [PPM]', 'Temp [C]', 'relHum [%]']
ax = data.plot(y=variables, lw=2, subplots=True, grid=True)
for a, lbl in zip(ax, variables):
    a.set_ylabel(lbl)

now = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
plt.tight_layout()
plt.savefig(f'../figs/sensor_data_plot_{now}.png')
